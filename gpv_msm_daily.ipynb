# %% [markdown]
# # GPV天気図（MSM用）

# %%
import numpy as np
import xarray as xr
from pathlib import Path
from module.gpv_panel_daily_msm import make_daily_weather_panel_multi_time

ncfile = Path("~/gpv_project/data/Z__C_RJTD_20240701000000_MSM_GPV_Rjp_L-pall_FH00-15_grib2.bin.nc").expanduser()
ds = xr.open_dataset(ncfile)

init = np.datetime64("2024-07-01T00:00:00")
times = [init + np.timedelta64(i * 6, 'h') for i in range(4)]
save_path = Path("~/Desktop/msm_weather_map.jpg").expanduser()
make_daily_weather_panel_multi_time(ds, times, save_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 12
#      10 times = [init + np.timedelta64(i * 6, 'h') for i in range(4)]
#      11 save_path = Path("~/Desktop/msm_weather_map.jpg").expanduser()
# ---> 12 make_daily_weather_panel_multi_time(ds, times, save_path)
#
# File ~/gpv_project/notebook/module/gpv_panel_daily_msm.py:25, in make_daily_weather_panel_multi_time(ds, times, save_path)
#      23 dsi = ds.sel(time=time)
#      24 plot_300hpa_height_wind(axes[0, col], dsi)
# ---> 25 plot_700hpa_temp_rh(axes[1, col], dsi)
#      26 plot_850hpa_temp_wind_w(axes[2, col], dsi)
#      27 plot_850hpa_thetae_stream(axes[3, col], dsi)
#
# File ~/gpv_project/notebook/module/gpv_plotter_msm.py:85, in plot_700hpa_temp_rh(ax, ds)
#      83 cbar = plt.colorbar(cf, ax=ax, orientation="vertical", shrink=0.6, pad=0.02)
#      84 ticks = cbar.get_ticks()
# ---> 85 cbar.ax.set_yticklabels([f"{l:.0f}" for l in ticks[:-1]] + ["30+"])
#      86 cbar.set_label("700hPa湿数 [℃]", fontsize=8)
#      88 # 500hPa等温線
#
# File ~/miniforge3/envs/met_env/lib/python3.11/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File ~/miniforge3/envs/met_env/lib/python3.11/site-packages/matplotlib/axis.py:2106, in Axis.set_ticklabels(self, labels, minor, fontdict, **kwargs)
#    2102 elif isinstance(locator, mticker.FixedLocator):
#    2103     # Passing [] as a list of labels is often used as a way to
#    2104     # remove all tick labels, so only error for > 0 labels
#    2105     if len(locator.locs) != len(labels) and len(labels) != 0:
# -> 2106         raise ValueError(
#    2107             "The number of FixedLocator locations"
#    2108             f" ({len(locator.locs)}), usually from a call to"
#    2109             " set_ticks, does not match"
#    2110             f" the number of labels ({len(labels)}).")
#    2111     tickd = {loc: lab for loc, lab in zip(locator.locs, labels)}
#    2112     func = functools.partial(self._format_with_dict, tickd)
#
# ValueError: The number of FixedLocator locations (13), usually from a call to set_ticks, does not match the number of labels (7).
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:527: UserWarning: Glyph 31561 (\N{CJK UNIFIED IDEOGRAPH-7B49}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:527: UserWarning: Glyph 39640 (\N{CJK UNIFIED IDEOGRAPH-9AD8}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:527: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:527: UserWarning: Glyph 32218 (\N{CJK UNIFIED IDEOGRAPH-7DDA}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:527: UserWarning: Glyph 12539 (\N{KATAKANA MIDDLE DOT}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:527: UserWarning: Glyph 39080 (\N{CJK UNIFIED IDEOGRAPH-98A8}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:524: UserWarning: Glyph 31561 (\N{CJK UNIFIED IDEOGRAPH-7B49}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:524: UserWarning: Glyph 39640 (\N{CJK UNIFIED IDEOGRAPH-9AD8}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:524: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:524: UserWarning: Glyph 32218 (\N{CJK UNIFIED IDEOGRAPH-7DDA}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:524: UserWarning: Glyph 12539 (\N{KATAKANA MIDDLE DOT}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:524: UserWarning: Glyph 39080 (\N{CJK UNIFIED IDEOGRAPH-98A8}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:527: UserWarning: Glyph 31561 (\N{CJK UNIFIED IDEOGRAPH-7B49}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:527: UserWarning: Glyph 39640 (\N{CJK UNIFIED IDEOGRAPH-9AD8}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:527: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:527: UserWarning: Glyph 32218 (\N{CJK UNIFIED IDEOGRAPH-7DDA}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:527: UserWarning: Glyph 12539 (\N{KATAKANA MIDDLE DOT}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:527: UserWarning: Glyph 39080 (\N{CJK UNIFIED IDEOGRAPH-98A8}) missing from font(s) DejaVu Sans.
#   super()._update_title_position(renderer)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:524: UserWarning: Glyph 31561 (\N{CJK UNIFIED IDEOGRAPH-7B49}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:524: UserWarning: Glyph 39640 (\N{CJK UNIFIED IDEOGRAPH-9AD8}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:524: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:524: UserWarning: Glyph 32218 (\N{CJK UNIFIED IDEOGRAPH-7DDA}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:524: UserWarning: Glyph 12539 (\N{KATAKANA MIDDLE DOT}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
# /Users/home/miniforge3/envs/met_env/lib/python3.11/site-packages/cartopy/mpl/geoaxes.py:524: UserWarning: Glyph 39080 (\N{CJK UNIFIED IDEOGRAPH-98A8}) missing from font(s) DejaVu Sans.
#   return super().draw(renderer=renderer, **kwargs)
